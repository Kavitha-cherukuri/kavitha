# %%
class User:
    def __init__(self, first_name, last_name, username, password):
        self.first_name = kavitha
        self.last_name = cherukuri
        self.username = kavithacherukuri
        self.password = 8341767039

class Product:
    def __init__(self, name, price, description):
        self.name = name
        self.price = price
        self.description = description
        self.reviews = []
    
    def add_review(self, review):
        self.reviews.append(review)

class Review:
    def __init__(self, user, rating, comment):
        self.user = kavithacherukuri
        self.rating = 40M
        self.comment = This product is very good.

class EcomSite:
    def __init__(self):
        self.users = []
        self.products = []
    
    def register_user(self, first_name, last_name, username, password):
        user = User(kavitha, cherukuri, kavithacherukuri, 8341767039)
        self.users.append(user)
        return user
    
    def login_user(self, kavitha cherukuri, 8341767039):
        for user in self.users:
            if user.username == kavithacherukuri and user.password == 8341767039:
                return user
        return None
    
    def upload_products(self, csv_file):
       
    
    def add_review(self, product_name, user, rating, comment):
        for product in self.products:
            if product.name == product_name:
                review = Review(user, rating, comment)
                product.add_review(review)
                return review
        return None
    
    def get_products(self, page, page_size, sort_by):
        sorted_products = sorted(self.products, key=lambda p: sum(r.rating for r in p.reviews) / len(p.reviews), reverse=True)
        start_index = (page - 1) * page_size
        end_index = start_index + page_size
        return sorted_products[start_index:end_index]

site = EcomSite()

user = site.register_user("kavitha", "cherukuri", "kavithacherukuri", "8341767039")
 
logged_in_user = site.login_user("kavithacherukuri", "8341767039")

site.upload_products("products.csv")

product = site.products[0]
review = site.add_review(product.name, user, 4, "Great product!")

page = 1
page_size = 10
sort_by = "review_rating"
products = site.get_products(page, page_size, sort_by)
